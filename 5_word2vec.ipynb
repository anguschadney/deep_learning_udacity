# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab, pyplot
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %matplotlib inline
pyplot.style.use('ggplot')

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    f = zipfile.ZipFile(filename)
    for name in f.namelist():
        return tf.compat.as_str(f.read(name)).split()
    f.close()

words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0    # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words    # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window    # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
        data_index = 0
        batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
        print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
        print('        batch:', [reverse_dictionary[bi] for bi in batch])
        print('        labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#         batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#         labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#         batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#         labels: ['a', 'originated', 'anarchism', 'term', 'originated', 'of', 'term', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size))
    )
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(
            softmax_weights, softmax_biases, embed, train_labels, num_sampled, vocabulary_size
        )
    )

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.817245
# Nearest to most: instantly, tactic, illuminate, dressage, sourceforge, botha, neared, frontispiece,
# Nearest to used: laika, affinity, myst, ideas, escuela, sacred, obstruction, commutators,
# Nearest to known: automatism, basis, alyattes, singleton, malaysian, cairns, nasdaq, lamborghini,
# Nearest to may: dato, retinal, endocytosis, inform, hearings, allen, telegram, waits,
# Nearest to can: zug, specialists, malan, eurozone, skillfully, residents, lddc, deuterium,
# Nearest to while: preface, vera, airman, arrangers, sahelian, janssen, hurtful, treatment,
# Nearest to these: disruptions, robotics, milford, maclachlan, toothed, threw, birdman, appendices,
# Nearest to american: birding, dnow, mention, jsr, cowan, seniors, uriah, beverly,
# Nearest to if: redeeming, palatalization, walsh, modernism, merwara, heterosexual, nicholson, nabla,
# Nearest to other: researched, afghanistan, orientalis, cgi, asis, obsessed, capacitive, francais,
# Nearest to as: tsvetaeva, bactria, interstate, carnage, ambition, fdr, marcellus, predominantly,
# Nearest to into: lammas, benchmarks, heterozygote, musa, robbins, incisors, fouled, differ,
# Nearest to nine: politicians, greenman, discard, idea, vermouth, perlman, courbet, available,
# Nearest to new: vignettes, safety, tuba, yoga, appropriated, predict, busting, salicylic,
# Nearest to their: shit, cbm, endothermic, amhr, octane, repeat, phased, marred,
# Nearest to about: mbox, chitin, hawaii, fastened, hamel, caused, keepers, emotional,
# Average loss at step 2000: 4.363618
# Average loss at step 4000: 3.862467
# Average loss at step 6000: 3.784736
# Average loss at step 8000: 3.687485
# Average loss at step 10000: 3.613583
# Nearest to most: instantly, hermetical, tactic, rare, neared, laity, pisano, guardians,
# Nearest to used: lemmy, sacred, welcoming, laika, rak, accumulate, trams, chemists,
# Nearest to known: rockies, ich, malaysian, automatism, oddity, lamborghini, zelda, iterate,
# Nearest to may: could, pandemic, can, foulke, would, dato, might, scrat,
# Nearest to can: would, could, may, conspirators, raced, pune, should, consuming,
# Nearest to while: illyria, preface, sahelian, vera, arrangers, slade, hurtful, kerala,
# Nearest to these: some, all, appendices, milford, robotics, disruptions, maclachlan, entrenched,
# Nearest to american: birding, roskilde, dnow, rotating, chagos, operand, tours, homininae,
# Nearest to if: where, ephemeral, telepathic, proudhon, portrait, safest, retrieved, fertilizers,
# Nearest to other: begining, afghanistan, sustaining, adjectives, researched, are, asis, luisa,
# Nearest to as: bailiff, became, by, leaving, cavern, over, harmonisation, repressions,
# Nearest to into: lammas, thematically, largest, traveled, intersects, placental, in, insoluble,
# Nearest to nine: eight, five, seven, six, zero, three, four, two,
# Nearest to new: lo, encore, amato, safety, busting, dte, vinnie, cogito,
# Nearest to their: his, its, rumoured, the, cbm, shit, lal, vested,
# Nearest to about: chitin, caused, highlighting, on, hawaii, fastened, jacket, poured,
# Average loss at step 12000: 3.603256
# Average loss at step 14000: 3.572704
# Average loss at step 16000: 3.412310
# Average loss at step 18000: 3.455685
# Average loss at step 20000: 3.539959
# Nearest to most: instantly, some, more, tactic, rare, hermetical, use, hipparcos,
# Nearest to used: lemmy, found, rak, welcoming, laika, trams, freaks, novo,
# Nearest to known: such, ich, rockies, called, automatism, iterate, lamborghini, oddity,
# Nearest to may: can, would, might, could, will, must, should, pandemic,
# Nearest to can: would, may, could, will, should, conspirators, must, to,
# Nearest to while: illyria, kerala, slade, differentiates, unity, could, arrangers, including,
# Nearest to these: some, all, many, appendices, several, such, milford, they,
# Nearest to american: birding, roskilde, french, jewish, dnow, alonso, aardvark, destroyer,
# Nearest to if: where, meades, when, though, proudhon, fertilizers, ephemeral, gave,
# Nearest to other: many, begining, some, various, afghanistan, different, asis, sustaining,
# Nearest to as: bailiff, ditches, became, when, placing, leaving, shoots, planting,
# Nearest to into: from, rt, on, lammas, internetworking, thematically, in, traveled,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to new: amato, dte, lo, busting, vinnie, grade, blacks, encore,
# Nearest to their: its, his, rumoured, the, ordinance, some, her, these,
# Nearest to about: poured, keepers, accreditation, on, jacket, chitin, galactic, kut,
# Average loss at step 22000: 3.497292
# Average loss at step 24000: 3.488285
# Average loss at step 26000: 3.481692
# Average loss at step 28000: 3.480330
# Average loss at step 30000: 3.502388
# Nearest to most: more, some, tactic, instantly, use, many, hipparcos, rare,
# Nearest to used: found, lemmy, allowed, known, developed, considered, referred, appear,
# Nearest to known: such, regarded, well, used, rockies, called, ich, iterate,
# Nearest to may: can, would, could, will, might, must, should, shall,
# Nearest to can: may, would, could, will, should, must, might, cannot,
# Nearest to while: could, were, when, but, although, illyria, mandola, including,
# Nearest to these: some, many, all, they, several, such, their, both,
# Nearest to american: birding, french, canadian, english, roskilde, alonso, international, german,
# Nearest to if: when, where, though, is, fertilizers, meades, gave, ephemeral,
# Nearest to other: different, begining, various, some, rather, historical, magistracy, these,
# Nearest to as: bailiff, madhava, ditches, for, planting, by, gediminas, marion,
# Nearest to into: from, internetworking, through, bl, rt, on, lammas, gastrointestinal,
# Nearest to nine: eight, seven, six, four, five, three, zero, one,
# Nearest to new: dte, amato, pint, grade, lo, encore, tritium, offensive,
# Nearest to their: its, his, the, her, ordinance, these, our, rumoured,
# Nearest to about: accreditation, props, licensed, benefited, on, jacket, poured, chitin,
# Average loss at step 32000: 3.503099
# Average loss at step 34000: 3.492487
# Average loss at step 36000: 3.452387
# Average loss at step 38000: 3.297334
# Average loss at step 40000: 3.430159
# Nearest to most: more, some, tactic, instantly, less, use, many, rare,
# Nearest to used: found, considered, known, available, responsible, described, lemmy, allowed,
# Nearest to known: such, regarded, used, well, rockies, iterate, ich, see,
# Nearest to may: can, will, would, could, might, must, should, cannot,
# Nearest to can: may, could, would, will, should, must, might, cannot,
# Nearest to while: although, when, however, after, could, but, are, was,
# Nearest to these: many, some, several, such, both, they, their, all,
# Nearest to american: french, canadian, birding, alonso, english, british, german, jewish,
# Nearest to if: when, where, though, is, primrose, meades, fertilizers, zach,
# Nearest to other: different, various, many, sustaining, monomer, some, rather, begining,
# Nearest to as: bailiff, facet, inductively, when, embryogenesis, cavern, cues, gediminas,
# Nearest to into: from, through, gastrointestinal, internetworking, rabat, rt, robbins, fled,
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Nearest to new: pint, dte, series, grade, habilis, ere, amato, vinnie,
# Nearest to their: its, his, her, our, the, them, ordinance, these,
# Nearest to about: accreditation, benefited, licensed, props, rearden, poured, chitin, pvp,
# Average loss at step 42000: 3.432401
# Average loss at step 44000: 3.455490
# Average loss at step 46000: 3.447471
# Average loss at step 48000: 3.349267
# Average loss at step 50000: 3.378351
# Nearest to most: more, some, many, less, tactic, use, instantly, gibbs,
# Nearest to used: known, allowed, found, written, described, considered, seen, available,
# Nearest to known: used, regarded, such, defined, well, described, called, part,
# Nearest to may: can, would, will, could, might, must, should, shall,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to while: when, although, after, however, but, before, is, without,
# Nearest to these: some, many, several, both, such, various, their, they,
# Nearest to american: canadian, birding, french, english, international, british, african, european,
# Nearest to if: when, where, though, dor, meades, although, manmade, depressive,
# Nearest to other: different, various, some, many, sustaining, these, those, distinct,
# Nearest to as: bailiff, ambition, vitis, planting, became, corneille, daoism, recurring,
# Nearest to into: through, from, rt, gastrointestinal, kearns, internetworking, during, fled,
# Nearest to nine: eight, seven, six, four, three, five, zero, one,
# Nearest to new: dte, habilis, pint, special, fifth, basic, sanjaks, vinnie,
# Nearest to their: its, his, her, the, these, several, both, our,
# Nearest to about: props, dramatised, benefited, rearden, licensed, letter, arranging, proposals,
# Average loss at step 52000: 3.436941
# Average loss at step 54000: 3.426294
# Average loss at step 56000: 3.438298
# Average loss at step 58000: 3.393224
# Average loss at step 60000: 3.390085
# Nearest to most: some, many, more, less, tactic, instantly, use, soak,
# Nearest to used: found, known, written, considered, required, available, allowed, described,
# Nearest to known: regarded, used, such, called, defined, part, possible, well,
# Nearest to may: can, would, will, could, might, should, must, shall,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to while: although, when, after, however, before, though, including, were,
# Nearest to these: many, some, several, both, such, those, their, all,
# Nearest to american: canadian, birding, european, british, french, english, international, german,
# Nearest to if: when, where, though, before, because, then, although, since,
# Nearest to other: different, various, many, sustaining, some, several, monomer, those,
# Nearest to as: bailiff, when, rockers, westwards, deducted, stouffer, planting, became,
# Nearest to into: through, from, rt, between, waterway, internetworking, fled, within,
# Nearest to nine: eight, six, seven, five, four, three, zero, one,
# Nearest to new: dte, newsletter, normative, particular, pint, habilis, oval, special,
# Nearest to their: its, his, her, the, our, these, whose, some,
# Nearest to about: benefited, props, dramatised, over, on, conferences, formalization, invisibility,
# Average loss at step 62000: 3.235701
# Average loss at step 64000: 3.255605
# Average loss at step 66000: 3.405551
# Average loss at step 68000: 3.392114
# Average loss at step 70000: 3.360108
# Nearest to most: more, many, some, less, use, instantly, all, tactic,
# Nearest to used: found, written, known, considered, required, allowed, seen, responsible,
# Nearest to known: regarded, used, such, defined, called, possible, described, part,
# Nearest to may: can, will, would, could, must, should, might, cannot,
# Nearest to can: may, could, would, will, must, might, should, cannot,
# Nearest to while: although, when, however, though, after, including, despite, but,
# Nearest to these: many, some, such, several, their, all, various, those,
# Nearest to american: canadian, british, birding, english, european, australian, african, international,
# Nearest to if: when, though, where, because, while, cannot, before, although,
# Nearest to other: different, various, many, sustaining, monomer, some, several, genetic,
# Nearest to as: vitis, goers, unfolded, burger, draw, bailiff, platinum, padding,
# Nearest to into: through, from, within, rt, between, waterway, internetworking, nice,
# Nearest to nine: eight, six, seven, five, four, three, zero, one,
# Nearest to new: normative, dte, tritium, safety, amato, aelius, maximally, civitas,
# Nearest to their: its, his, her, the, our, these, my, your,
# Nearest to about: props, benefited, arranging, on, over, dramatised, conferences, ptah,
# Average loss at step 72000: 3.371319
# Average loss at step 74000: 3.347483
# Average loss at step 76000: 3.310048
# Average loss at step 78000: 3.355905
# Average loss at step 80000: 3.378306
# Nearest to most: more, many, some, less, tactic, instantly, pacemaker, soak,
# Nearest to used: known, found, required, written, allowed, responsible, available, considered,
# Nearest to known: regarded, used, defined, called, described, possible, such, written,
# Nearest to may: can, could, should, will, would, must, might, cannot,
# Nearest to can: could, may, will, would, must, cannot, might, should,
# Nearest to while: although, though, however, when, after, including, whilst, were,
# Nearest to these: several, many, some, various, those, such, both, their,
# Nearest to american: british, canadian, australian, international, european, birding, french, german,
# Nearest to if: when, though, before, where, cannot, although, then, because,
# Nearest to other: various, different, many, local, others, monomer, including, sustaining,
# Nearest to as: looters, platinum, bailiff, after, unfolded, demoralized, when, marcellus,
# Nearest to into: through, from, within, misogynist, rt, around, across, during,
# Nearest to nine: eight, seven, five, six, four, three, zero, one,
# Nearest to new: dte, aelius, normative, amato, civitas, oval, dignified, tritium,
# Nearest to their: its, his, her, our, your, my, the, these,
# Nearest to about: arranging, basics, over, dramatised, props, conferences, benefited, families,
# Average loss at step 82000: 3.405267
# Average loss at step 84000: 3.413754
# Average loss at step 86000: 3.392170
# Average loss at step 88000: 3.352049
# Average loss at step 90000: 3.364919
# Nearest to most: more, less, some, many, tactic, all, especially, pacemaker,
# Nearest to used: required, known, found, allowed, seen, referred, designed, considered,
# Nearest to known: regarded, used, such, described, called, possible, defined, opposed,
# Nearest to may: can, would, could, should, will, must, might, cannot,
# Nearest to can: could, may, will, must, would, cannot, should, might,
# Nearest to while: although, when, though, after, however, before, during, were,
# Nearest to these: several, some, many, various, such, those, both, all,
# Nearest to american: british, australian, canadian, french, european, international, african, birding,
# Nearest to if: when, though, where, before, although, because, since, after,
# Nearest to other: various, different, many, local, sustaining, including, some, hogarth,
# Nearest to as: baden, bailiff, rockers, ambushes, platinum, applicable, corrino, alexandre,
# Nearest to into: through, from, within, around, misogynist, lance, off, under,
# Nearest to nine: eight, seven, six, five, four, zero, three, births,
# Nearest to new: particular, different, oval, delft, aelius, visit, normative, polynomial,
# Nearest to their: his, its, her, our, your, my, the, whose,
# Nearest to about: props, dramatised, arranging, over, concerning, leonhard, conferences, bart,
# Average loss at step 92000: 3.396896
# Average loss at step 94000: 3.254741
# Average loss at step 96000: 3.360289
# Average loss at step 98000: 3.238737
# Average loss at step 100000: 3.355332
# Nearest to most: more, less, tactic, especially, particularly, many, use, extremely,
# Nearest to used: required, allowed, designed, found, known, given, written, considered,
# Nearest to known: regarded, such, used, described, possible, defined, opposed, viewed,
# Nearest to may: can, could, should, would, must, might, will, cannot,
# Nearest to can: could, may, would, will, must, should, might, cannot,
# Nearest to while: when, although, though, after, before, however, if, where,
# Nearest to these: several, some, many, various, those, which, all, both,
# Nearest to american: british, canadian, australian, french, italian, international, birding, alonso,
# Nearest to if: when, though, before, where, while, although, because, does,
# Nearest to other: various, different, others, sustaining, older, many, individual, literary,
# Nearest to as: bailiff, minster, traversal, fia, goers, burger, ans, reference,
# Nearest to into: through, within, from, onto, off, around, in, misogynist,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to new: different, particular, modern, oval, ere, alkaloid, pilot, dignified,
# Nearest to their: its, his, her, our, your, the, several, these,
# Nearest to about: arranging, concerning, dramatised, props, leonhard, basics, correlate, on,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))    # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                                     ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to Word2Vec is called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
